# %%
from gym_smartgrid.envs import SmartGridEnv6
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d9d54a9fb9de> in <module>
# ----> 1 from gym_smartgrid.envs import SmartGridEnv6
#
# ~/Code/ULG_2019/gym-smartgrid/gym_smartgrid/__init__.py in <module>
# ----> 1 from gym.envs.registration import register
#       2
#       3 register(
#       4     id='acgrid-v0',
#       5     entry_point='gym_smartgrid.envs:FooEnv',
#
# ModuleNotFoundError: No module named 'gym'

# %%
if __name__ == '__main__':
    env = SmartGridEnv6()
    env.reset()
    for _ in range(50):
        env.render('save')
        env.step(env.action_space.sample()) # take a random action
    history = env.close(path='test_history.csv')

# %%
    import pandas as pd
    loaded_history = pd.read_csv('test_history.csv', )
